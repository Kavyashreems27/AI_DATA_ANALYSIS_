# %%
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <title>Image Insertion Example</title>
  <style>
    .image-container {
      width: 500px;
      margin: 20px auto;
      border: 1px solid #ccc;
      padding: 10px;
      text-align: center;
    }

    .image-container img {
      width: 100%;
      height: auto;
      border-radius: 8px;
    }
  </style>
</head>
<body>

  <h1>Welcome to My Webpage</h1>

  <div class="image-container">
    <a href="https://example.com">
      <img src="images/sample.jpg" alt="Sample Image Description">
    </a>
    <p>This is a sample image placed inside a div container and linked to another page.</p>
  </div>

</body>
</html>
