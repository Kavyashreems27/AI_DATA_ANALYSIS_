# %%
# Ques 3 - Data Manipulation with Pandas

import pandas as pd
import seaborn as sns

# Load the Iris dataset
df = sns.load_dataset('iris')

# Add a new column: petal length to petal width ratio
df['petal_ratio'] = df['petal_length'] / df['petal_width']

# Display the first 5 rows with the new column
print("First 5 rows with the new 'petal_ratio' column:")
print(df.head())
# Out:
# First 5 rows with the new 'petal_ratio' column:
#    sepal_length  sepal_width  petal_length  petal_width species  petal_ratio
# 0           5.1          3.5           1.4          0.2  setosa          7.0
# 1           4.9          3.0           1.4          0.2  setosa          7.0
# 2           4.7          3.2           1.3          0.2  setosa          6.5
# 3           4.6          3.1           1.5          0.2  setosa          7.5
# 4           5.0          3.6           1.4          0.2  setosa          7.0
