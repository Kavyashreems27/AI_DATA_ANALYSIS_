# %%
import pandas as pd
from scipy.stats import ks_2samp

# Load your training and new data into pandas DataFrames
# For example:
# train_df = pd.read_csv('train_data.csv')
# new_df = pd.read_csv('new_data.csv')

# List of numerical features to check for drift
numerical_features = ['feature1', 'feature2', 'feature3']  # replace with your actual feature names

# Perform KS test for each feature
for feature in numerical_features:
    statistic, p_value = ks_2samp(train_df[feature], new_df[feature])
    if p_value < 0.05:
        print(f"Data drift detected in feature '{feature}' (p-value: {p_value:.5f})")
    else:
        print(f"No data drift detected in feature '{feature}' (p-value: {p_value:.5f})")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-29c53c0f32be> in <cell line: 0>()
#      12 # Perform KS test for each feature
#      13 for feature in numerical_features:
# ---> 14     statistic, p_value = ks_2samp(train_df[feature], new_df[feature])
#      15     if p_value < 0.05:
#      16         print(f"Data drift detected in feature '{feature}' (p-value: {p_value:.5f})")
#
# NameError: name 'train_df' is not defined
